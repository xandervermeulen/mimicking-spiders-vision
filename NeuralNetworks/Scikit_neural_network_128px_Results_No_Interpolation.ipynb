# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
# Inlezen van CSV-bestand
dataPositions = pd.read_csv('../test-data/positions_xyz_128px_full.csv')
dataCoordinates = pd.read_csv('../test-data/red_ball_coordinates_128px_full.csv')
dataPositions.shape, dataCoordinates.shape
# Out:
# ((4711, 3), (4711, 14))

# %%
combined = pd.concat([dataCoordinates, dataPositions], axis=1)
# remove the rows with to more than 3 NaN values

combined = combined.dropna(thresh=combined.shape[1]-3)
combined
# Out:
#        u0    v0     u1    v1   u2    v2    u3    v3     u4    v4  u5  v5  \
# 7     2.0  48.5   88.0  46.0  0.0  92.5  47.0  89.0   91.0  90.0 NaN NaN
# 8     2.0  50.0   88.5  47.0  0.5  93.0  47.0  90.0   91.0  90.0 NaN NaN
# 9     3.0  50.0   89.0  48.0  0.5  94.0  47.0  90.0   91.5  91.0 NaN NaN
# 10    3.5  51.0   89.5  48.5  1.0  95.0  48.0  91.0   92.0  92.0 NaN NaN
# 11    4.0  52.0   89.0  49.0  1.0  96.0  48.0  92.0   92.5  93.0 NaN NaN
# ...   ...   ...    ...   ...  ...   ...   ...   ...    ...   ...  ..  ..
# 3643  5.0  11.0  109.0  10.0  2.0  68.0  56.0  68.0  116.0  68.0 NaN NaN
# 3644  5.0  12.0  108.0  11.0  2.0  69.0  56.0  69.0  115.0  70.0 NaN NaN
# 3645  4.0  13.0  107.0  13.0  2.0  71.0  56.0  71.0  115.0  72.0 NaN NaN
# 3646  4.0  15.0  107.0  15.0  1.0  73.0  55.0  73.0  115.0  73.0 NaN NaN
# 3647  4.0  17.0  106.0  17.0  1.0  75.0  55.0  74.0  114.0  75.0 NaN NaN
#
#          u6     v6          x         y         z
# 7      68.5  120.5  10.033960  3.860552  15.79055
# 8      68.5  120.5  10.006010  3.956561  15.88656
# 9      68.5  120.5   9.974871  4.051584  15.98158
# 10     68.5  120.5   9.940582  4.145517  16.07552
# 11     68.5  120.5   9.903183  4.238255  16.16825
# ...     ...    ...        ...       ...       ...
# 3643  122.0  124.0   8.673822  1.483025   7.95000
# 3644  122.0  125.0   8.682408  1.524471   7.95000
# 3645  122.5  126.0   8.690976  1.567635   7.95000
# 3646  123.0  127.0   8.699528  1.612468   7.95000
# 3647  123.5  128.0   8.708062  1.658920   7.95000
#
# [1574 rows x 17 columns]

# %%
X = combined.iloc[:, :14] # select all rows and columns from 0 to 13
y = combined.iloc[:, 14:] # select x y z output columns

# %% [markdown]
# ### Data Preprocessing

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=2)
dfX = imputer.fit_transform(X)
y = imputer.fit_transform(y)

# %% [markdown]
# ### Splitting the dataset into the Training set and Test set

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split

# Splitting the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(dfX, y, test_size=0.2, random_state=42)

# Splitting the training data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)

# %%
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_val_scaled = scaler_X.transform(X_val)
X_test_scaled = scaler_X.transform(X_test)

scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train)
y_val_scaled = scaler_y.transform(y_val)
y_test_scaled = scaler_y.transform(y_test)

X_train_scaled.shape[0], X_val_scaled.shape[0], X_test_scaled.shape[0]
# Out:
# (944, 315, 315)

# %% [markdown]
# ### Hyperparameter tuning

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neural_network import MLPRegressor

# Define a parameter grid for the MLPRegressor
param_grid = {
    'model__hidden_layer_sizes': [ (50, 50), (150, 100, 50), (200, 150, 100)],
    'model__activation': ['identity', 'logistic', 'tanh', 'relu'],
    'model__solver': ['sgd', 'adam'],
    'model__learning_rate': ['constant', 'invscaling', 'adaptive'],
    'model__learning_rate_init': [0.001, 0.01, 0.1],
    'model__max_iter': [10000, 20000, 28000],
    'model__early_stopping': [True],
}

# Create a pipeline with an MLPRegressor model
pipeline = Pipeline([
    ('model', MLPRegressor(random_state=42))
])

# Perform a randomized search over the parameter grid
random_search = RandomizedSearchCV(pipeline, param_distributions=param_grid, n_iter=100, cv=5, n_jobs=-1, verbose=2, random_state=42)

# %% [markdown]
# #### Train the model

# %%
random_search.fit(X_train_scaled, y_train_scaled)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# C:\Users\xande\venv\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 15 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\xande\venv\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\xande\venv\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "C:\Users\xande\venv\lib\site-packages\sklearn\pipeline.py", line 427, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "C:\Users\xande\venv\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "C:\Users\xande\venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 753, in fit
#     return self._fit(X, y, incremental=False)
#   File "C:\Users\xande\venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 476, in _fit
#     self._fit_stochastic(
#   File "C:\Users\xande\venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 660, in _fit_stochastic
#     self._update_no_improvement_count(early_stopping, X_val, y_val)
#   File "C:\Users\xande\venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 709, in _update_no_improvement_count
#     self.validation_scores_.append(self._score(X_val, y_val))
#   File "C:\Users\xande\venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 1612, in _score
#     return r2_score(y, y_pred)
#   File "C:\Users\xande\venv\lib\site-packages\sklearn\utils\_param_validation.py", line 187, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\xande\venv\lib\site-packages\sklearn\metrics\_regression.py", line 989, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\xande\venv\lib\site-packages\sklearn\metrics\_regression.py", line 101, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\xande\venv\lib\site-packages\sklearn\utils\validation.py", line 957, in check_array
#     _assert_all_finite(
#   File "C:\Users\xande\venv\lib\site-packages\sklearn\utils\validation.py", line 122, in _assert_all_finite
#     _assert_all_finite_element_wise(
#   File "C:\Users\xande\venv\lib\site-packages\sklearn\utils\validation.py", line 171, in _assert_all_finite_element_wise
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\xande\venv\lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [ 9.74852635e-01 -1.07394532e-02  5.10545486e-01  6.60012393e-01
#   4.50720714e-01 -8.86789836e+01  9.12276661e-01  7.94271271e-01
#  -1.07292655e-02  9.57750851e-01  9.71107309e-01  9.57750851e-01
#  -1.07292655e-02  7.98561669e-01  7.31568316e-01 -1.07292655e-02
#   9.08666442e-01  9.37036909e-01  7.70545834e-01  7.99552582e-01
#   9.45815564e-01  7.98561669e-01  9.17798184e-01  7.79620892e-01
#   9.53949175e-01  4.91030791e-01  9.41042803e-01 -6.35511760e-03
#   9.57423299e-01  7.83712913e-01  7.19733567e-01  7.98831431e-01
#   9.03111260e-01  9.37115133e-01  9.47385101e-01  9.42254663e-01
#   7.74548558e-01  9.17798184e-01  9.09521889e-01             nan
#   9.12276661e-01  9.33322720e-01  9.29198361e-01  4.50720714e-01
#   9.82983385e-01  7.73816452e-01  3.39058743e-01  9.22187231e-01
#  -1.63458148e-02  9.41855781e-01  4.33072939e-01  7.82980944e-01
#   9.52149606e-01  7.31568316e-01             nan  9.33322720e-01
#   9.03111260e-01 -1.37927023e+00  8.01182795e-01 -6.38597109e-03
#   6.20283959e-01 -8.86789836e+01  7.98561669e-01  9.51126898e-01
#   9.08666442e-01 -8.79646959e-01  5.39631042e-01  9.56957743e-01
#   9.12276661e-01  9.69444090e-01  7.98561669e-01  9.68316150e-01
#   7.83712913e-01  9.01163649e-01 -1.07394532e-02  7.85861337e-01
#   7.51270481e-01 -1.54679347e-02  7.99552582e-01  9.74852635e-01
#   9.68316150e-01  9.71736545e-01  9.41771692e-01  9.71737808e-01
#   9.22187231e-01  4.91030791e-01             nan  8.82187538e-01
#  -1.07292655e-02  9.71107309e-01  7.94271271e-01  7.74548558e-01
#   7.85861337e-01  9.51126898e-01  7.31568316e-01  7.79620892e-01
#   9.78405027e-01  9.71107309e-01 -6.38597109e-03  7.94271271e-01]
#   warnings.warn(
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('model',
#                                               MLPRegressor(random_state=42))]),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'model__activation': ['identity',
#                                                               'logistic',
#                                                               'tanh', 'relu'],
#                                         'model__early_stopping': [True],
#                                         'model__hidden_layer_sizes': [(50, 50),
#                                                                       (150, 100,
#                                                                        50),
#                                                                       (200, 150,
#                                                                        100)],
#                                         'model__learning_rate': ['constant',
#                                                                  'invscaling',
#                                                                  'adaptive'],
#                                         'model__learning_rate_init': [0.001,
#                                                                       0.01,
#                                                                       0.1],
#                                         'model__max_iter': [10000, 20000,
#                                                             28000],
#                                         'model__solver': ['sgd', 'adam']},
#                    random_state=42, verbose=2)

# %% [markdown]
# #### Result of the hyperparameter tuning

# %%
model = random_search.best_estimator_

# %%
print('fBest parameters found:\n', random_search.best_params_)
# Out:
# fBest parameters found:
#  {'model__solver': 'sgd', 'model__max_iter': 28000, 'model__learning_rate_init': 0.1, 'model__learning_rate': 'adaptive', 'model__hidden_layer_sizes': (150, 100, 50), 'model__early_stopping': True, 'model__activation': 'relu'}

# %% [markdown]
# #### Make Predictions

# %%
y_val_pred_scaled = model.predict(X_val_scaled)
y_val_pred = scaler_y.inverse_transform(y_val_pred_scaled)

# %% [markdown]
# #### Evaluate the model

# %%
from utils.evaluate import evaluate_model

mse_val, mae_val, r2_val = evaluate_model(y_val, y_val_pred, "Validation")
# Out:
# Mean Squared Error on Validation Set: 0.02518223487168306
# Mean Absolute Error on Validation Set: 0.08996011591691883
# R2 Score on Validation set: 0.9903877718949848

# %%
y_test_pred_scaled = model.predict(X_test_scaled)
y_test_pred = scaler_y.inverse_transform(y_test_pred_scaled)

# %%
mse_test, mae_test, r2_test = evaluate_model(y_test, y_test_pred, "Test")
# Out:
# Mean Squared Error on Test Set: 0.0401116029181059
# Mean Absolute Error on Test Set: 0.09943660326493141
# R2 Score on Test set: 0.9882983546980918

# %% [markdown]
# #### Visualize the results
# The test data is randomized so the plot won't show a clean trajectory

# %%
from utils.plot_maker_gaussian_process import plot_maker_3d

plot_maker_3d(np.array(y_test)[:10], np.array(y_test_pred)[:10], "Predictions on Test Set")

# %% [markdown]
# # Make Predictions on new data

# %%
test_data = pd.read_csv('../interpolated-data/red_ball_coordinates_128px_2024-02-27_13h38m.csv', delimiter=',', decimal='.')
test_result = pd.read_csv('../interpolated-data/positions_xyz_2024-02-27_13h38m.csv', delimiter=',', decimal='.')

# %%
new_combined = pd.concat([test_data, test_result], axis=1)
new_combined = new_combined.dropna(thresh=new_combined.shape[1]-3)
new_combined = new_combined

# %%
new_X = new_combined.iloc[:, :14]
new_y = new_combined.iloc[:, 14:]
new_X.shape, new_y.shape
# Out:
# ((1474, 14), (1474, 3))

# %%
new_X_imputed = imputer.fit_transform(new_X)

new_X_scaled = scaler_X.fit_transform(new_X_imputed)
new_y_scaled = scaler_y.fit_transform(new_y)

# %%
new_y_pred_scaled = model.predict(new_X_scaled)

# %%
new_y_pred = scaler_y.inverse_transform(new_y_pred_scaled)

# %%
new_mse, new_mae, new_r2 = evaluate_model(new_y, new_y_pred, "New Data")
# Out:
# Mean Squared Error on New Data Set: 1.7683719094424142
# Mean Absolute Error on New Data Set: 0.9664338417759901
# R2 Score on New Data set: 0.44748429465661027

# %%
plot_maker_3d(np.array(new_y), np.array(new_y_pred), "Predictions on New Data")
